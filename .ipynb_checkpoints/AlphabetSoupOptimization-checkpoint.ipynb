# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
from sklearn.svm import SVC

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# WARNING:tensorflow:From C:\Users\17139\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# ...

# %%
# Drop the non-beneficial ID columns, 'Application_Type' and 'Status'.
# Here I realized the importance of capitalizing the columns just as they are in df for code to work. Whoo! 
application_df.drop(['APPLICATION_TYPE', 'STATUS'], axis=1, inplace=True)
application_df.head()
# Out:
#         EIN                                      NAME       AFFILIATION  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB       Independent
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR       Independent
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  CompanySponsored
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  CompanySponsored
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT       Independent
#
#   CLASSIFICATION      USE_CASE  ORGANIZATION     INCOME_AMT  \
# 0          C1000    ProductDev   Association              0
# 1          C2000  Preservation  Co-operative         1-9999
# 2          C3000    ProductDev   Association              0
# 3          C2000  Preservation         Trust    10000-24999
# 4          C1000     Heathcare         Trust  100000-499999
#
#   SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0                      N     5000              1
# 1                      N   108590              1
# ...

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()

print(unique_values)
# Out:
# EIN                       34299
# NAME                      19568
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_values = application_df["APPLICATION_TYPE"].value_counts()
print(application_type_values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'APPLICATION_TYPE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
# ...
